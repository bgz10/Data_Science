# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import urllib
import matplotlib.dates as mdates

# %%
pd.options.display.max_rows = 999

# %%
df = pd.read_csv('stud-stat-anonymous.csv')
df
# Out:
#      Unnamed: 0      Id Total Absence             Class/Group  \
# 0             0  214366          100%  Web and Soft Electives
# 1             1  680092          100%  Web and Soft Electives
# 2             2  906441          100%  Web and Soft Electives
# 3             3  432875          100%  Web and Soft Electives
# 4             4  146518          100%  Web and Soft Electives
# 5             5  864755          100%  Web and Soft Electives
# 6             6  464972          100%  Web and Soft Electives
# 7             7  728877          100%  Web and Soft Electives
# 8             8  419492          100%  Web and Soft Electives
# 9             9  205702          100%  Web and Soft Electives
# 10           10  379715          100%                   SD18i
# 11           11  668900          100%                   SD18i
# 12           12  695323          100%                   SD18i
# 13           13  196127          100%                   SD18i
# ...

# %%
df.sort_values(by=['Id'])
# Out:
#      Unnamed: 0      Id Total Absence             Class/Group  \
# 53           53  104328         57.5%                 ITS19w1
# 26           26  105304         90.9%  Web and Soft Electives
# 73           73  107766           46%                  SD19w1
# 145         145  110311         18.4%  Web and Soft Electives
# 57           57  111019         54.5%  Web and Soft Electives
# 126         126  115992         25.9%                   SD18i
# 117         117  128523         27.6%                   SD18i
# 195         195  130119          6.2%                  ITS18a
# 43           43  135632         67.8%                 ITS19w1
# 150         150  140798         17.6%  Web and Soft Electives
# 4             4  146518          100%  Web and Soft Electives
# 102         102  147899         35.6%                 ITS19w1
# 62           62  153094         49.2%                   SD18i
# 60           60  153731         51.7%                 Web19w1
# ...

# %%
df.sort_values(by=['Class/Group'])
# Out:
#      Unnamed: 0      Id Total Absence             Class/Group  \
# 111         111  298679         29.2%                  ITS18a
# 44           44  858209         67.7%                  ITS18a
# 78           78  579153         44.6%                  ITS18a
# 144         144  658419         18.5%                  ITS18a
# 195         195  130119          6.2%                  ITS18a
# 52           52  280032         58.5%                  ITS18a
# 45           45  196056         67.7%                  ITS18a
# 207         207  239722          3.1%                  ITS18a
# 205         205  710120          3.1%                  ITS18a
# 34           34  723459         84.6%                  ITS18a
# 178         178  175927          9.2%                  ITS18a
# 30           30  615329         86.2%                  ITS18a
# 29           29  613200         87.7%                  ITS18a
# 81           81  301757         43.1%                  ITS18a
# ...

# %%
d = dict(tuple(df.groupby('Class/Group')))
d
# Out:
# {'ITS18a':      Unnamed: 0      Id Total Absence Class/Group  \
#  111         111  298679         29.2%      ITS18a
#  216         216  700477            0%      ITS18a
#  217         217  223338            0%      ITS18a
#  24           24  542155         96.9%      ITS18a
#  23           23  215571         96.9%      ITS18a
#  71           71  272447         47.7%      ITS18a
#  25           25  825970         96.9%      ITS18a
#  208         208  688021          3.1%      ITS18a
#  135         135  647586         21.5%      ITS18a
#  134         134  941580         21.5%      ITS18a
#  103         103  321954         35.4%      ITS18a
#  170         170  446063         10.6%      ITS18a
#  95           95  994560         36.9%      ITS18a
#  94           94  749091         36.9%      ITS18a
#  154         154  648071         16.9%      ITS18a
#  81           81  301757         43.1%      ITS18a
#  29           29  613200         87.7%      ITS18a
# ...

# %%
d['ITS18a']
# Out:
#      Unnamed: 0      Id Total Absence Class/Group  \
# 111         111  298679         29.2%      ITS18a
# 216         216  700477            0%      ITS18a
# 217         217  223338            0%      ITS18a
# 24           24  542155         96.9%      ITS18a
# 23           23  215571         96.9%      ITS18a
# 71           71  272447         47.7%      ITS18a
# 25           25  825970         96.9%      ITS18a
# 208         208  688021          3.1%      ITS18a
# 135         135  647586         21.5%      ITS18a
# 134         134  941580         21.5%      ITS18a
# 103         103  321954         35.4%      ITS18a
# 170         170  446063         10.6%      ITS18a
# 95           95  994560         36.9%      ITS18a
# 94           94  749091         36.9%      ITS18a
# 154         154  648071         16.9%      ITS18a
# 81           81  301757         43.1%      ITS18a
# 29           29  613200         87.7%      ITS18a
# 30           30  615329         86.2%      ITS18a
# ...

# %%
d['ITS19w1']
# Out:
#      Unnamed: 0      Id Total Absence Class/Group                 Subject  \
# 41           41  179935         70.1%     ITS19w1  Intro til IT Sikkerhed
# 40           40  397345         70.1%     ITS19w1  Intro til IT Sikkerhed
# 130         130  287874         24.1%     ITS19w1  Intro til IT Sikkerhed
# 218         218  293438            0%     ITS19w1  Intro til IT Sikkerhed
# 27           27  543558         88.5%     ITS19w1  Intro til IT Sikkerhed
# 22           22  296184          100%     ITS19w1  Intro til IT Sikkerhed
# 35           35  396493           77%     ITS19w1  Intro til IT Sikkerhed
# 38           38  879390         71.3%     ITS19w1  Intro til IT Sikkerhed
# 187         187  690648          7.4%     ITS19w1  Intro til IT Sikkerhed
# 115         115  676326         27.7%     ITS19w1  Intro til IT Sikkerhed
# 102         102  147899         35.6%     ITS19w1  Intro til IT Sikkerhed
# 114         114  637923         28.7%     ITS19w1  Intro til IT Sikkerhed
# ...

# %%
len(d)
# Out:
# 6

# %%
for i in d:
    print(i)
# Out:
# ITS18a
# ITS19w1
# SD18i
# SD19w1
# Web and Soft Electives
# Web19w1

# %%
d['Web and Soft Electives']
# Out:
#      Unnamed: 0      Id Total Absence             Class/Group  \
# 1             1  680092          100%  Web and Soft Electives
# 55           55  541960         54.5%  Web and Soft Electives
# 99           99  920684         36.4%  Web and Soft Electives
# 5             5  864755          100%  Web and Soft Electives
# 97           97  458246         36.4%  Web and Soft Electives
# 49           49  694322         63.6%  Web and Soft Electives
# 56           56  811371         54.5%  Web and Soft Electives
# 31           31  699025         86.2%  Web and Soft Electives
# 58           58  699958           53%  Web and Soft Electives
# 48           48  371558         63.6%  Web and Soft Electives
# 63           63  889786         48.8%  Web and Soft Electives
# 65           65  952612         48.5%  Web and Soft Electives
# 39           39  666991         71.2%  Web and Soft Electives
# 129         129  666744         24.3%  Web and Soft Electives
# ...

# %%
its18 = d['ITS18a']
its19 = d['ITS19w1']
sd18 = d['SD18i']
sd19 = d['SD19w1']
wase = d['Web and Soft Electives']
web19 = d['Web19w1']

# %%
its18
# Out:
#      Unnamed: 0      Id Total Absence Class/Group  \
# 111         111  298679         29.2%      ITS18a
# 216         216  700477            0%      ITS18a
# 217         217  223338            0%      ITS18a
# 24           24  542155         96.9%      ITS18a
# 23           23  215571         96.9%      ITS18a
# 71           71  272447         47.7%      ITS18a
# 25           25  825970         96.9%      ITS18a
# 208         208  688021          3.1%      ITS18a
# 135         135  647586         21.5%      ITS18a
# 134         134  941580         21.5%      ITS18a
# 103         103  321954         35.4%      ITS18a
# 170         170  446063         10.6%      ITS18a
# 95           95  994560         36.9%      ITS18a
# 94           94  749091         36.9%      ITS18a
# 154         154  648071         16.9%      ITS18a
# 81           81  301757         43.1%      ITS18a
# 29           29  613200         87.7%      ITS18a
# 30           30  615329         86.2%      ITS18a
# ...

# %%
its19
# Out:
#      Unnamed: 0      Id Total Absence Class/Group                 Subject  \
# 41           41  179935         70.1%     ITS19w1  Intro til IT Sikkerhed
# 40           40  397345         70.1%     ITS19w1  Intro til IT Sikkerhed
# 130         130  287874         24.1%     ITS19w1  Intro til IT Sikkerhed
# 218         218  293438            0%     ITS19w1  Intro til IT Sikkerhed
# 27           27  543558         88.5%     ITS19w1  Intro til IT Sikkerhed
# 22           22  296184          100%     ITS19w1  Intro til IT Sikkerhed
# 35           35  396493           77%     ITS19w1  Intro til IT Sikkerhed
# 38           38  879390         71.3%     ITS19w1  Intro til IT Sikkerhed
# 187         187  690648          7.4%     ITS19w1  Intro til IT Sikkerhed
# 115         115  676326         27.7%     ITS19w1  Intro til IT Sikkerhed
# 102         102  147899         35.6%     ITS19w1  Intro til IT Sikkerhed
# 114         114  637923         28.7%     ITS19w1  Intro til IT Sikkerhed
# ...

# %%
sd18
# Out:
#      Unnamed: 0      Id Total Absence Class/Group Subject Absence  \
# 36           36  635774         72.4%       SD18i     DLS  68.42%
# 14           14  879153          100%       SD18i     DLS    100%
# 15           15  890965          100%       SD18i     DLS    100%
# 16           16  577358          100%       SD18i     DLS    100%
# 37           37  646053         72.1%       SD18i     DLS  68.42%
# 12           12  695323          100%       SD18i     DLS    100%
# 198         198  460452          5.7%       SD18i     DLS  13.16%
# 17           17  247407          100%       SD18i     DLS    100%
# 62           62  153094         49.2%       SD18i     DLS  55.26%
# 20           20  268525          100%       SD18i     DLS    100%
# 191         191  863970          6.9%       SD18i     DLS  15.79%
# 192         192  908589          6.9%       SD18i     DLS  15.79%
# 19           19  873190          100%       SD18i     DLS    100%
# ...

# %%
sd19
# Out:
#      Unnamed: 0      Id Total Absence Class/Group    Subject Absence  \
# 82           82  523463         42.9%      SD19w1  Databases    100%
# 190         190  828049            7%      SD19w1  Databases      0%
# 185         185  707742          8.1%      SD19w1  Databases      0%
# 73           73  107766           46%      SD19w1  Databases     50%
# 79           79  212186         44.6%      SD19w1  Databases    100%
# 101         101  334312         35.6%      SD19w1  Databases     50%
# 194         194  480068          6.5%      SD19w1  Databases      0%
# 174         174  642754         10.2%      SD19w1  Databases     50%
# 201         201  610938          4.8%      SD19w1  Databases      0%
# 172         172  783966         10.2%      SD19w1  Databases      0%
# 199         199  643901          5.1%      SD19w1  Databases     50%
# 171         171  200123         10.5%      SD19w1  Databases      0%
# 173         173  580861         10.2%      SD19w1  Databases     50%
# ...

# %%
wase
# Out:
#      Unnamed: 0      Id Total Absence             Class/Group  \
# 1             1  680092          100%  Web and Soft Electives
# 55           55  541960         54.5%  Web and Soft Electives
# 99           99  920684         36.4%  Web and Soft Electives
# 5             5  864755          100%  Web and Soft Electives
# 97           97  458246         36.4%  Web and Soft Electives
# 49           49  694322         63.6%  Web and Soft Electives
# 56           56  811371         54.5%  Web and Soft Electives
# 31           31  699025         86.2%  Web and Soft Electives
# 58           58  699958           53%  Web and Soft Electives
# 48           48  371558         63.6%  Web and Soft Electives
# 63           63  889786         48.8%  Web and Soft Electives
# 65           65  952612         48.5%  Web and Soft Electives
# 39           39  666991         71.2%  Web and Soft Electives
# 129         129  666744         24.3%  Web and Soft Electives
# ...

# %%
wase.sort_values(by=['Subject','Subject.1','Subject.2'])
# Out:
#      Unnamed: 0      Id Total Absence             Class/Group  \
# 1             1  680092          100%  Web and Soft Electives
# 55           55  541960         54.5%  Web and Soft Electives
# 99           99  920684         36.4%  Web and Soft Electives
# 5             5  864755          100%  Web and Soft Electives
# 97           97  458246         36.4%  Web and Soft Electives
# 49           49  694322         63.6%  Web and Soft Electives
# 56           56  811371         54.5%  Web and Soft Electives
# 48           48  371558         63.6%  Web and Soft Electives
# 65           65  952612         48.5%  Web and Soft Electives
# 26           26  105304         90.9%  Web and Soft Electives
# 57           57  111019         54.5%  Web and Soft Electives
# 123         123  534870         27.3%  Web and Soft Electives
# 50           50  437341         63.6%  Web and Soft Electives
# 113         113  882972         28.8%  Web and Soft Electives
# ...

# %%
se = dict(tuple(df.groupby('Subject')))
for i in se:
    print(i)
# Out:
# Angular
# Big Data
# DLS
# Data Science
# Databases
# Intro til IT Sikkerhed
# Quantum Computing
# Security for mobile devices
# Software Design Patterns
# Web Development
# Web Security

# %%
web19
# Out:
#      Unnamed: 0      Id Total Absence Class/Group          Subject Absence  \
# 90           90  622904         41.4%     Web19w1  Web Development      0%
# 89           89  774783         41.4%     Web19w1  Web Development      0%
# 88           88  878517         41.4%     Web19w1  Web Development      0%
# 87           87  305265         41.4%     Web19w1  Web Development      0%
# 86           86  636158         41.4%     Web19w1  Web Development      0%
# 68           68  443095         48.3%     Web19w1  Web Development  22.22%
# 69           69  703392         48.3%     Web19w1  Web Development  11.11%
# 67           67  614503         48.3%     Web19w1  Web Development  11.11%
# 66           66  546140         48.3%     Web19w1  Web Development  66.67%
# 193         193  839114          6.9%     Web19w1  Web Development  22.22%
# 93           93  920332         37.9%     Web19w1  Web Development  55.56%
# ...
